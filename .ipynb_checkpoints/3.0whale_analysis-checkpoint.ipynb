# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_return_csv = Path("./Resources/whale_returns.csv")

whale_df = pd.read_csv(whale_return_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
whale_df.head()
# it was found that by setting the date as the index on import simplified the cleaning and concating process for the portfolios.
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop Nulls

whale_df = whale_df.dropna()


whale_df.isnull().sum()

# confirming the nulls were dropped
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_return_csv = Path("./Resources/algo_returns.csv")

algo_df = pd.read_csv(algo_return_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls


algo_df = algo_df.dropna()

algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csvpath = Path("./Resources/sp500_history.csv")
sp500_df = pd.read_csv(csvpath, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.sort_index(inplace=True)



sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types

sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")
sp500_df["Close"] = sp500_df["Close"].str.replace(",", "")
# the comas were removed after the Instructor siad there were some in the data, though a quick visual inspection did not reveal any.

sp500_df['Close'] = sp500_df['Close'].astype('float')
sp500_df.head()
# Out:
# C:\Users\Fintech\anaconda3\envs\alpacaenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Increase the size of the plot, x & y axis and title
sp500_df.plot(figsize=(15,10),rot=60, title="SP 500",ylabel="Level")

# the y axis is labeled 'Level', though traditional there is no label for the y axis for a chart of the SP 500.
# Out:
# <AxesSubplot:title={'center':'SP 500'}, xlabel='Date', ylabel='Level'>

# %%
# Calculate Daily Returns

sp500_dr_df = sp500_df.pct_change()

sp500_dr_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_dr_df=sp500_dr_df.dropna()

sp500_dr_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_dr_df = sp500_dr_df.rename(columns ={
    'Close': 'SP500 Daily Returns'
})
sp500_dr_df.head()
# Out:
#             SP500 Daily Returns
# Date
# 2012-10-02             0.000872
# 2012-10-03             0.003624
# 2012-10-04             0.007174
# 2012-10-05            -0.000322
# 2012-10-08            -0.003457

# %%
sp500_dr_df.sort_index(inplace=True)
sp500_dr_df.head()
# Out:
#             SP500 Daily Returns
# Date
# 2012-10-02             0.000872
# 2012-10-03             0.003624
# 2012-10-04             0.007174
# 2012-10-05            -0.000322
# 2012-10-08            -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

combined_pf = pd.concat([whale_df, algo_df, sp500_dr_df], axis='columns', join='inner')
combined_pf
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_pf.plot(figsize=(15,10),rot=60, title="Daily Returns",ylabel="Percentage Change")
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date', ylabel='Percentage Change'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumlative_returns = (1 + combined_pf).cumprod() - 1
#cumlative_returns.head()

# Plot cumulative returns
cumlative_returns.plot(figsize=(15,10),rot=60, title="Cumlative Returns",ylabel="Percent Change")
# Out:
# <AxesSubplot:title={'center':'Cumlative Returns'}, xlabel='Date', ylabel='Percent Change'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

combined_pf.plot(kind="box", figsize=(15,10),rot=60, title="Returns",ylabel="Percent Change")
# Out:
# <AxesSubplot:title={'center':'Returns'}, ylabel='Percent Change'>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

combined_std = combined_pf.std()
combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500 Daily Returns            0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = combined_pf['SP500 Daily Returns'].std()

combined_pf.std()>sp500_std
# Determine which portfolios are riskier than the S&P 500
#compare_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500 Daily Returns            False
# dtype: bool

# %% [markdown]
# ### *The Portfolios that are more risky are: Tiger Global, Berkshire Hathaway.*

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_ann_std = combined_std* np.sqrt(252)
combined_ann_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500 Daily Returns            0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

combined_pf.rolling(window=21).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-16                   0.006711            0.006224
# 2019-04-17                   0.006773            0.006370
# 2019-04-18                   0.006633            0.006303
# 2019-04-22                   0.005915            0.006400
# 2019-04-23                   0.004315            0.005695
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                          NaN                     NaN       NaN
# ...

# %%
# Plot the rolling standard deviation

combined_pf.rolling(window=21).std().plot(figsize=(15,10), rot=60, title="Rolling Standard Deviation",ylabel="Level of Vol")
# Out:
# <AxesSubplot:title={'center':'Rolling Standard Deviation'}, xlabel='Date', ylabel='Level of Vol'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

combined_corr = combined_pf.corr()
combined_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500 Daily Returns                           0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
combined_corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_296e8_row0_col0, #T_296e8_row1_col1, #T_296e8_row2_col2, #T_296e8_row3_col3, #T_296e8_row4_col4, #T_296e8_row5_col5, #T_296e8_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_296e8_row0_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_296e8_row0_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_296e8_row0_col3, #T_296e8_row3_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_296e8_row0_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_296e8_row0_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_296e8_row0_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_296e8_row1_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_296e8_row1_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_296e8_row1_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_296e8_row1_col4 {
#   background-color: #6282ea;
# ...

# %%
# Display de correlation matrix

#import seaborn as sns
#sns.heatmap(combined_corr, annot=True)

# This is the coding to creat a heatmap from seaborn. I have kept it as a refference.

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio

covariance = combined_pf['Algo 1'].cov(combined_pf['SP500 Daily Returns'])
covariance
# Out:
# 1.821774999163274e-05

# %%
# Calculate variance of S&P 500

variance = combined_pf['SP500 Daily Returns'].var()
variance
# Out:
# 7.316632424648712e-05

# %%
# Computing beta

beta = covariance / variance
beta
# Out:
# 0.24899091459425635

# %%
# Plot beta trend

rolling_covariance = combined_pf['Algo 1'].rolling(window=60).cov(combined_pf['SP500 Daily Returns'])

rolling_variance = combined_pf['SP500 Daily Returns'].rolling(window=60).var()

rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(15,10), rot=60, title="Beta",ylabel="Change")
# Out:
# <AxesSubplot:title={'center':'Beta'}, xlabel='Date', ylabel='Change'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window

combined_pf.ewm(halflife=21).mean()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000511           -0.000802
# 2015-03-05                   0.001718            0.000878
# 2015-03-06                  -0.000808           -0.000291
# 2015-03-09                  -0.000511            0.000673
# ...                               ...                 ...
# 2019-04-16                   0.001480            0.000448
# 2019-04-17                   0.001338            0.000223
# 2019-04-18                   0.001341            0.000256
# 2019-04-22                   0.001214            0.000009
# 2019-04-23                   0.001407            0.000122
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.001532               -0.001089 -0.005320
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios

sharpe_ratios = (combined_pf.mean() * 252) / (combined_pf.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500 Daily Returns            0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios.plot(kind='bar', figsize=(15,10), rot=60, title='Portfolios', ylabel='Sharpe Ratio')
# Out:
# <AxesSubplot:title={'center':'Portfolios'}, ylabel='Sharpe Ratio'>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# ### *-Algo 1 provides more Sharpe Ratio than the SP 500 and the Whales while Algo 2 provides more Sharpe Ratio than Paulson and Tiger prtfolios.*

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock

costco_csv = Path("./Resources/costco_2021.csv")
costco_df = pd.read_csv(costco_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
costco_df.head()
# Out:
#              Close
# Date
# 2015-03-03  147.37
# 2015-03-04  147.17
# 2015-03-05  151.17
# 2015-03-06  149.54
# 2015-03-09  150.68

# %%
costco_df = costco_df.rename(columns ={
    'Close': 'COST'
})
costco_df.head()
# Out:
#               COST
# Date
# 2015-03-03  147.37
# 2015-03-04  147.17
# 2015-03-05  151.17
# 2015-03-06  149.54
# 2015-03-09  150.68

# %%
# Reading data from 2nd stock

toyota_csv = Path("./Resources/toyota_2021.csv")
toyota_df = pd.read_csv(toyota_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
toyota_df.head()
# Out:
#              Close
# Date
# 2015-03-03  135.40
# 2015-03-04  135.52
# 2015-03-05  134.90
# 2015-03-06  134.89
# 2015-03-09  135.39

# %%
toyota_df = toyota_df.rename(columns ={
    'Close': 'TM'
})
toyota_df.head()
# Out:
#                 TM
# Date
# 2015-03-03  135.40
# 2015-03-04  135.52
# 2015-03-05  134.90
# 2015-03-06  134.89
# 2015-03-09  135.39

# %%
# Reading data from 3rd stock

amazon_csv = Path("./Resources/amazon_2021.csv")
amazon_df = pd.read_csv(amazon_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)
amazon_df.head()
# Out:
#              Close
# Date
# 2015-03-03  384.61
# 2015-03-04  382.72
# 2015-03-05  387.83
# 2015-03-06  380.09
# 2015-03-09  378.56

# %%
amazon_df = amazon_df.rename(columns ={
    'Close': 'AMZN'
})
amazon_df.head()
# Out:
#               AMZN
# Date
# 2015-03-03  384.61
# 2015-03-04  382.72
# 2015-03-05  387.83
# 2015-03-06  380.09
# 2015-03-09  378.56

# %%
# Combine all stocks in a single DataFrame

custom_df = pd.concat([costco_df, toyota_df, amazon_df], axis='columns', join='inner')
custom_df.tail(10)
# Out:
#               COST      TM     AMZN
# Date
# 2019-04-08  246.52  122.24  1849.86
# 2019-04-09  244.91  122.06  1835.84
# 2019-04-10  245.61  122.18  1847.33
# 2019-04-11  241.24  121.04  1844.07
# 2019-04-12  241.95  122.40  1843.06
# 2019-04-15  246.33  121.97  1844.87
# 2019-04-16  245.34  121.75  1863.04
# 2019-04-17  245.56  124.08  1864.82
# 2019-04-18  245.81  125.16  1861.69
# 2019-04-22  243.42  124.16  1887.31

# %% [markdown]
# ## Reset Date index
#
# ### *This step was accomplished during import.*

# %% [markdown]
# ## Reorganize portfolio data by having a column per symbol
#
# ### *This step was accompished right after import*

# %%
#custom_df.isnull().sum()
#ustom_df.dtypes
# Calculate daily returns

custom_daily_rtn = custom_df.pct_change()
custom_daily_rtn
# Out:
#                 COST        TM      AMZN
# Date
# 2015-03-03       NaN       NaN       NaN
# 2015-03-04 -0.001357  0.000886 -0.004914
# 2015-03-05  0.027179 -0.004575  0.013352
# 2015-03-06 -0.010783 -0.000074 -0.019957
# 2015-03-09  0.007623  0.003707 -0.004025
# ...              ...       ...       ...
# 2019-04-15  0.018103 -0.003513  0.000982
# 2019-04-16 -0.004019 -0.001804  0.009849
# 2019-04-17  0.000897  0.019138  0.000955
# 2019-04-18  0.001018  0.008704 -0.001678
# 2019-04-22 -0.009723 -0.007990  0.013762
#
# [1042 rows x 3 columns]

# %%
# Drop NA

custom_daily_rtn = custom_daily_rtn.dropna()
custom_df.isnull().sum()
# Out:
# COST    0
# TM      0
# AMZN    0
# dtype: int64

# %%
# Display sample data

custom_daily_rtn
# Out:
#                 COST        TM      AMZN
# Date
# 2015-03-04 -0.001357  0.000886 -0.004914
# 2015-03-05  0.027179 -0.004575  0.013352
# 2015-03-06 -0.010783 -0.000074 -0.019957
# 2015-03-09  0.007623  0.003707 -0.004025
# 2015-03-10 -0.016724 -0.012556 -0.023906
# ...              ...       ...       ...
# 2019-04-15  0.018103 -0.003513  0.000982
# 2019-04-16 -0.004019 -0.001804  0.009849
# 2019-04-17  0.000897  0.019138  0.000955
# 2019-04-18  0.001018  0.008704 -0.001678
# 2019-04-22 -0.009723 -0.007990  0.013762
#
# [1041 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
# Display sample data

portfolio_returns = custom_daily_rtn.dot(weights)
portfolio_returns.head()
# Out:
# Date
# 2015-03-04   -0.001795
# 2015-03-05    0.011985
# 2015-03-06   -0.010271
# 2015-03-09    0.002435
# 2015-03-10   -0.017729
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

all_rtns = pd.concat([portfolio_returns, combined_pf], axis='columns', join='inner')
all_rtns
# Out:
#                    0  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04 -0.001795                   0.002230            0.003241
# 2015-03-05  0.011985                   0.004016            0.004076
# 2015-03-06 -0.010271                  -0.007905           -0.003574
# 2015-03-09  0.002435                   0.000582            0.004225
# 2015-03-10 -0.017729                  -0.010263           -0.005341
# ...              ...                        ...                 ...
# 2019-04-15  0.005191                  -0.001422           -0.001156
# 2019-04-16  0.001342                   0.002699            0.000388
# 2019-04-17  0.006997                  -0.002897           -0.006467
# 2019-04-18  0.002681                   0.001448            0.001222
# 2019-04-22 -0.001317                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %%
# Renaked the columns to simplfy things.

all_rtns.columns=['Weighted', 'Soros', 'Paulson', 'Tiger', 'Berkshire', 'Algo 1', 'Algo 2', 'SP 500']
all_rtns
# Out:
#             Weighted     Soros   Paulson     Tiger  Berkshire    Algo 1  \
# Date
# 2015-03-04 -0.001795  0.002230  0.003241 -0.002534   0.004213 -0.008589
# 2015-03-05  0.011985  0.004016  0.004076  0.002355   0.006726 -0.000955
# 2015-03-06 -0.010271 -0.007905 -0.003574 -0.008481  -0.013098 -0.004957
# 2015-03-09  0.002435  0.000582  0.004225  0.005843  -0.001652 -0.005447
# 2015-03-10 -0.017729 -0.010263 -0.005341 -0.012079  -0.009739 -0.001392
# ...              ...       ...       ...       ...        ...       ...
# 2019-04-15  0.005191 -0.001422 -0.001156  0.000398  -0.010492 -0.004331
# 2019-04-16  0.001342  0.002699  0.000388 -0.000831   0.000837 -0.006945
# 2019-04-17  0.006997 -0.002897 -0.006467 -0.004409   0.003222 -0.010301
# 2019-04-18  0.002681  0.001448  0.001222  0.000582   0.001916 -0.000588
# 2019-04-22 -0.001317 -0.002586 -0.007333 -0.003640  -0.001088  0.000677
#
#               Algo 2    SP 500
# Date
# 2015-03-04  0.002416 -0.004389
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

all_rtns.isnull().sum()
# Out:
# Weighted     0
# Soros        0
# Paulson      0
# Tiger        0
# Berkshire    0
# Algo 1       0
# Algo 2       0
# SP 500       0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

all_rtns_vol = all_rtns.std() * np.sqrt(252)
all_rtns_vol.sort_values(inplace=True)
all_rtns_vol
# Out:
# Paulson      0.111556
# Algo 1       0.121058
# Soros        0.125406
# Algo 2       0.132475
# SP 500       0.135831
# Weighted     0.171582
# Tiger        0.173072
# Berkshire    0.205148
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation

all_rtns.rolling(window=21).std().plot(figsize=(15,10), rot=60, title="Rolling 21 day Standard Deviation",ylabel="Change")
# Out:
# <AxesSubplot:title={'center':'Rolling 21 day Standard Deviation'}, xlabel='Date', ylabel='Change'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

all_rtns_corr = all_rtns.corr()
all_rtns_corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_21320_row0_col0, #T_21320_row1_col1, #T_21320_row2_col2, #T_21320_row3_col3, #T_21320_row4_col4, #T_21320_row5_col5, #T_21320_row6_col6, #T_21320_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_21320_row0_col1, #T_21320_row0_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_21320_row0_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_21320_row0_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_21320_row0_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_21320_row0_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_21320_row0_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_21320_row1_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_21320_row1_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_21320_row1_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Plot beta trend

covari_60 = all_rtns['Weighted'].rolling(window=60).cov(all_rtns['SP 500'])
covari_60.plot(figsize=(15,10), rot=60, title="Rolling 60 day Covariance of my Weighted Portfolio and the SP 500",ylabel="Change")
# Out:
# <AxesSubplot:title={'center':'Rolling 60 day Covariance of my Weighted Portfolio and the SP 500'}, xlabel='Date', ylabel='Change'>

# %%
vari_60 = all_rtns['SP 500'].rolling(window=60).var()
vari_60.plot(figsize=(15,10), rot=60, title="Variance of the SP 500",ylabel="Change")
# Out:
# <AxesSubplot:title={'center':'Variance of the SP 500'}, xlabel='Date', ylabel='Change'>

# %%
rolling_b = covari_60 / vari_60
rolling_b.plot(figsize=(15, 10), title='Rolling 60-Day Beta', ylabel='Beta')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta'}, xlabel='Date', ylabel='Beta'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

sharpe_r = (all_rtns.mean() * 252) / (all_rtns.std() * np.sqrt(252))
sharpe_r
# Out:
# Weighted     1.101498
# Soros        0.345506
# Paulson     -0.480959
# Tiger       -0.129556
# Berkshire    0.614872
# Algo 1       1.374206
# Algo 2       0.486307
# SP 500       0.641630
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_r.plot(kind='bar', figsize=(15,10), rot=60, title='Portfolios', ylabel='Sharpe Ratio')
# Out:
# <AxesSubplot:title={'center':'Portfolios'}, ylabel='Sharpe Ratio'>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# ### *My weighted portfolio provides more 'Sharpe' than all the other portfolios as well as the SP 500, save for Algo 1.*
